# %% [markdown]
# # nomao dataset

# %%
# Imports
import os
import sys
BASE_DIR = os.path.dirname(os.getcwd())
sys.path.append(BASE_DIR)
import torch
import numpy as np
import pandas as pd

# Opendataval
from dataval.dataloader import Register, DataFetcher, mix_labels, add_gauss_noise
from dataval.datavaluation import NDDV, NDSV
from dataval.experiment import ExperimentMediator

import warnings
warnings.filterwarnings("ignore")
# Out:
# [KeOps] Compiling cuda jit compiler engine ...
# [KeOps] Warning : There were warnings or errors compiling formula :
# In file included from /home/kunyu/anaconda3/envs/zyliang_tju/lib/python3.10/site-packages/keopscore/binders/nvrtc/nvrtc_jit.cpp:21:
# /home/kunyu/anaconda3/envs/zyliang_tju/lib/python3.10/site-packages/keopscore/binders/nvrtc/nvrtc_jit.cpp: In function ‘int Compile(const char*, const char*, int, int, const char*)’:
# <command-line>: error: ‘nvrtcGetCUBINSize’ was not declared in this scope; did you mean ‘nvrtcGetPTXSize’?
# /home/kunyu/anaconda3/envs/zyliang_tju/lib/python3.10/site-packages/keopscore/include/utils_pe.h:6:26: note: in definition of macro ‘NVRTC_SAFE_CALL’
#     6 |     nvrtcResult result = x;                                       \
#       |                          ^
# /home/kunyu/anaconda3/envs/zyliang_tju/lib/python3.10/site-packages/keopscore/binders/nvrtc/nvrtc_jit.cpp:90:21: note: in expansion of macro ‘nvrtcGetTARGETSize’
#    90 |     NVRTC_SAFE_CALL(nvrtcGetTARGETSize(prog, &targetSize));
#       |                     ^~~~~~~~~~~~~~~~~~
# <command-line>: error: ‘nvrtcGetCUBIN’ was not declared in this scope; did you mean ‘nvrtcGetPTX’?
# /home/kunyu/anaconda3/envs/zyliang_tju/lib/python3.10/site-packages/keopscore/include/utils_pe.h:6:26: note: in definition of macro ‘NVRTC_SAFE_CALL’
#     6 |     nvrtcResult result = x;                                       \
#       |                          ^
# /home/kunyu/anaconda3/envs/zyliang_tju/lib/python3.10/site-packages/keopscore/binders/nvrtc/nvrtc_jit.cpp:93:21: note: in expansion of macro ‘nvrtcGetTARGET’
#    93 |     NVRTC_SAFE_CALL(nvrtcGetTARGET(prog, target));
#       |                     ^~~~~~~~~~~~~~
#
# OK

# %%
DataFetcher.datasets_available()
# Out:
# {'2dplanes',
#  'MiniBooNE',
#  'adult',
#  'bbc',
#  'bbc-embeddings',
#  'breast_cancer',
#  'challenge-iris',
#  'cifar10',
#  'cifar10-embeddings',
#  'cifar100',
#  'cifar100-embeddings',
#  'creditcard',
#  'diabetes',
#  'digits',
#  'echoMonths',
#  'election',
#  'electricity',
#  'fashion',
#  'fmnist-embeddings',
#  'fried',
#  'gaussian_classifier',
#  'gaussian_classifier_high_dim',
#  'imdb',
#  'imdb-embeddings',
#  'iris',
#  'linnerud',
#  'lowbwt',
#  'mnist',
#  'mnist-embeddings',
#  'mv',
#  'nomao',
#  'pol',
#  'stl10-embeddings',
#  'stock',
#  'svhn-embeddings',
#  'vehicle_sensIT',
#  'wave_energy',
#  'webdata_wXa'}

# %% [markdown]
# ## [Step 1] Set up an environment
# `ExperimentMediator` is a fundamental concept in establishing the `opendataval` environment. It empowers users to configure hyperparameters, including a dataset, a type of synthetic noise, and a prediction model. With  `ExperimentMediator`, users can effortlessly compute various data valuation algorithms.
#
# The following code cell demonstrates how to set up `ExperimentMediator` with a pre-registered dataset and a prediction model.
# - Dataset: adult
# - Model: sklearn's logistic regression model
# - Metric: Classification accuracy

# %%
dataset_name = "nomao"
train_count, valid_count, test_count, meta_count = 10000, 1000, 3000, 1000
noise_rate = 0.1
noise_kwargs = {'noise_rate': noise_rate}
max_epoch = 3
batch_size = 100
lr = 0.01
random_state = 42
train_kwargs = {"epochs": max_epoch, "batch_size": batch_size, "lr": lr}
model_name = "classifiermlp"   # "sklogreg"
# model_name = "LogisticRegression"
metric_name = "accuracy"
cache_dir = "../data_files/"
add_noise = mix_labels
noise_type = "mix_labels"
device = 'cpu'

exper_med = ExperimentMediator.model_factory_setup(
    dataset_name=dataset_name,
    cache_dir=cache_dir,  
    force_download=False,
    train_count=train_count,
    valid_count=valid_count,
    test_count=test_count,
    meta_count=meta_count,
    add_noise=add_noise, 
    noise_kwargs=noise_kwargs,
    train_kwargs=train_kwargs,
    random_state = random_state,
    model_name=model_name,
    metric_name=metric_name,
    device=device
)
# Out:
# Base line model metric_name='accuracy': perf=0.9303333163261414

# %% [markdown]
# A full list of registered datasets can be found [here](https://github.com/opendataval/opendataval/blob/main/opendataval/dataloader/fetcher.py#L121). A list of available  prediction models can be found [here](https://github.com/opendataval/opendataval/blob/main/opendataval/model/__init__.py#L111).

# %% [markdown]
# ## [Step 2] Compute data values
# `opendataval` provides various state-of-the-art data valuation algorithms. `ExperimentMediator.compute_data_values()` computes data values.

# %%
data_evaluators = [NDSV(mfg_epochs=50, base_model=model_name, meta_interval=4, Ntime=2, batch_size=batch_size, weight_decay=0, meta_weight_decay=0,meta_hidden_size=100)]

# %%
# %%time
# compute data values.
exper_med = exper_med.compute_data_values(data_evaluators=data_evaluators)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:01<01:17,  1.58s/it]
# Epoch: 0, Test Accuracy: 91.70%
#   4%|▍         | 2/50 [00:03<01:15,  1.57s/it]
# Epoch: 1, Test Accuracy: 91.80%
#   6%|▌         | 3/50 [00:04<01:18,  1.67s/it]
# Epoch: 2, Test Accuracy: 91.33%
#   8%|▊         | 4/50 [00:06<01:14,  1.62s/it]
# Epoch: 3, Test Accuracy: 92.77%
#  10%|█         | 5/50 [00:08<01:11,  1.59s/it]
# Epoch: 4, Test Accuracy: 90.40%
#  12%|█▏        | 6/50 [00:09<01:09,  1.57s/it]
# Epoch: 5, Test Accuracy: 93.30%
#  14%|█▍        | 7/50 [00:11<01:07,  1.57s/it]
# Epoch: 6, Test Accuracy: 93.57%
#  16%|█▌        | 8/50 [00:12<01:05,  1.57s/it]
# Epoch: 7, Test Accuracy: 94.13%
#  18%|█▊        | 9/50 [00:14<01:09,  1.68s/it]
# Epoch: 8, Test Accuracy: 93.63%
#  20%|██        | 10/50 [00:16<01:06,  1.66s/it]
# Epoch: 9, Test Accuracy: 93.33%
#  22%|██▏       | 11/50 [00:17<01:03,  1.62s/it]
# Epoch: 10, Test Accuracy: 94.43%
#  24%|██▍       | 12/50 [00:19<01:01,  1.62s/it]
# Epoch: 11, Test Accuracy: 93.53%
#  26%|██▌       | 13/50 [00:20<00:58,  1.58s/it]
# Epoch: 12, Test Accuracy: 94.23%
#  28%|██▊       | 14/50 [00:22<00:56,  1.57s/it]
# Epoch: 13, Test Accuracy: 93.43%
#  30%|███       | 15/50 [00:23<00:54,  1.56s/it]
# Epoch: 14, Test Accuracy: 92.90%
#  32%|███▏      | 16/50 [00:25<00:53,  1.58s/it]
# Epoch: 15, Test Accuracy: 92.23%
#  34%|███▍      | 17/50 [00:27<00:51,  1.57s/it]
# Epoch: 16, Test Accuracy: 93.80%
#  36%|███▌      | 18/50 [00:28<00:49,  1.54s/it]
# Epoch: 17, Test Accuracy: 93.90%
#  38%|███▊      | 19/50 [00:30<00:47,  1.53s/it]
# Epoch: 47, Test Accuracy: 94.83%
#  98%|█████████▊| 49/50 [01:15<00:01,  1.56s/it]
# Epoch: 48, Test Accuracy: 95.03%
# 100%|██████████| 50/50 [01:17<00:00,  1.54s/it]
# Epoch: 49, Test Accuracy: 95.00%
# Elapsed time NDSV(mfg_epochs=50, base_model=classifiermlp, meta_interval=4, Ntime=2, batch_size=100, weight_decay=0, meta_weight_decay=0, meta_hidden_size=100): 0:01:18.149846
# CPU times: user 40min 50s, sys: 5.47 s, total: 40min 55s
# Wall time: 1min 18s

# %% [markdown]
# ## [Step 3] Evaluate data values

# %%
from dataval.experiment.exper_methods import (
    discover_corrupted_sample,
    noisy_detection,
    remove_high_low,
    remove_high_value,
    remove_low_value,
    add_low_high,
    add_high_value,
    add_low_value,
    save_dataval
)
from matplotlib import pyplot as plt

# %%
# Saving the results with percent 5%
percent = 0.05
output_dir = f"../results/NDDV_{device}_{dataset_name}_{model_name}_{noise_type}_{noise_rate=}_{train_count=}_{percent=}/"
exper_med.set_output_directory(output_dir)
output_dir
# Out:
# '../results/NDDV_cpu_nomao_classifiermlp_mix_labels_noise_rate=0.1_train_count=10000_percent=0.05/'

# %% [markdown]
# ### Noisy data detection
# - `noisy_detection` performs the noisy data detection task and evaluates the F1-score of each data valuation algorithm's prediction. The higher, the better.
#   - noisy data: mislabeled data

# %%
exper_med.evaluate(noisy_detection, save_output=True)
# Out:
#                                                     kmeans_f1
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.728161

# %% [markdown]
# ### Discover noisy samples
# - `discover_corrupted_sample` visualizes how well noisy data points are identified when a fraction of dataset is inspected.

# %%
fig = plt.figure(figsize=(12, 5))
df, fig = exper_med.plot(discover_corrupted_sample, fig, col=2, percnet=percent, save_output=True)

# %% [markdown]
# ### Point removal experiment
# - `remove_high_low` performs the point removal experiment. Each data valution algorithm, it provides two curves: one is removing data in a descending order (orange), the other is in an ascending order (blue). As for the orange (resp. blue) curve, the lower (resp. upper), the better.

# %%
fig = plt.figure(figsize=(12, 5))
df_resp, fig = exper_med.plot(remove_high_low, fig, col=2, percnet=percent, save_output=True)

# %%
fig = plt.figure(figsize=(12, 5))
df, fig = exper_med.plot(remove_high_value, fig, col=2, percnet=percent, save_output=True)

# %%
fig = plt.figure(figsize=(12, 5))
df, fig = exper_med.plot(remove_low_value, fig, col=2, percnet=percent, save_output=True)

# %%
df_resp # it provides complete information for generating point-removal experiment figures.
# Out:
#                                                    remove_least_influential_first_Metrics.ACCURACY  \
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                        0.939333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                        0.942333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                        0.945667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                        0.944667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                        0.940667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                            0.94
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                        0.929667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                           0.934
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                           0.933
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                        0.928333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                        0.930667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                           0.932
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                           0.936
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                        0.926333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                        0.919667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                        0.928333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                        0.913333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                           0.923
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                           0.906
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                        0.848333
#
#                                                    remove_most_influential_first_Metrics.ACCURACY  \
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                       0.936333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                       0.935667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                          0.936
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                       0.941667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                       0.934667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                          0.913
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                       0.915667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                          0.905
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                          0.911
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                       0.821333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                       0.798667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                       0.776667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                       0.730667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                       0.617667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                       0.358333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                       0.208333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                       0.100667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                       0.083333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                       0.083667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                       0.092333
#
#                                                     axis
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.0
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...  0.05
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.1
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...  0.15
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.2
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...  0.25
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.3
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...  0.35
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.4
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...  0.45
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.5
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...  0.55
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.6
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...  0.65
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.7
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...  0.75
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.8
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...  0.85
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.9
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...  0.95

# %%
fig = plt.figure(figsize=(12, 5))
df_addp, fig = exper_med.plot(add_low_high, fig, col=2, percnet=percent, save_output=True)

# %%
fig = plt.figure(figsize=(12, 5))
df, fig = exper_med.plot(add_high_value, fig, col=2, percnet=percent, save_output=True)

# %%
fig = plt.figure(figsize=(12, 5))
df, fig = exper_med.plot(add_low_value, fig, col=2, percnet=percent, save_output=True)

# %%
df_addp
# Out:
#                                                    add_least_influential_first_Metrics.ACCURACY  \
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                     0.084333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                     0.078333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                     0.122667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                     0.202333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                     0.434333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                     0.558333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                     0.619667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                        0.717
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                     0.795667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                         0.91
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                        0.905
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                     0.919667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                     0.916333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                        0.931
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                     0.936667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                     0.933333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                     0.933333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                     0.934333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                     0.926333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                     0.938667
#
#                                                    add_most_influential_first_Metrics.ACCURACY  \
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                    0.934667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                        0.94
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                    0.933667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                       0.937
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                    0.944667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                    0.935667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                       0.933
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                    0.938333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                       0.939
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                    0.941667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                    0.943667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                       0.941
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                    0.940333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                    0.939333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                       0.936
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                    0.943333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                    0.941667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                        0.93
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                       0.941
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                    0.934667
#
#                                                     axis
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...  0.95
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.9
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...  0.85
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.8
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...  0.75
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.7
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...  0.65
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.6
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...  0.55
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.5
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...  0.45
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.4
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...  0.35
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.3
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...  0.25
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.2
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...  0.15
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.1
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...  0.05
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.0

# %% [markdown]
# ### Save data values
# - `save_dataval` stores computed data values at `{output_dir}/save_dataval.csv`.

# %%
exper_med.evaluate(save_dataval, save_output=True)
# Out:
#                                                    indices data_values
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   20556    0.002693
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   12350    0.002738
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   14709    0.002523
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   25448    0.002792
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   24098   -0.020053
# ...                                                    ...         ...
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   23892     0.00262
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   30650    0.002827
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...    7453    0.002335
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...     102    0.002639
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...     898    0.002321
#
# [10000 rows x 2 columns]

# %% [markdown]
# ### percent is 0.1

# %%
# Saving the results with percent 10%
percent = 0.1
output_dir = f"../results/NDDV_{device}_{dataset_name}_{model_name}_{noise_type}_{noise_rate=}_{train_count=}_{percent=}/"
exper_med.set_output_directory(output_dir)
output_dir
# Out:
# '../results/NDDV_cpu_nomao_classifiermlp_mix_labels_noise_rate=0.1_train_count=10000_percent=0.1/'

# %%
exper_med.evaluate(noisy_detection, save_output=True)
# Out:
#                                                     kmeans_f1
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.728161

# %%
fig = plt.figure(figsize=(12, 5))
df, fig = exper_med.plot(discover_corrupted_sample, fig, col=2, percnet=percent, save_output=True)

# %%
fig = plt.figure(figsize=(12, 5))
df_resp, fig = exper_med.plot(remove_high_low, fig, col=2, percnet=percent, save_output=True)

# %%
fig = plt.figure(figsize=(12, 5))
df, fig = exper_med.plot(remove_high_value, fig, col=2, percnet=percent, save_output=True)

# %%
fig = plt.figure(figsize=(12, 5))
df, fig = exper_med.plot(remove_low_value, fig, col=2, percnet=percent, save_output=True)

# %%
fig = plt.figure(figsize=(12, 5))
df_resp, fig = exper_med.plot(add_low_high, fig, col=2, percnet=percent, save_output=True)

# %%
fig = plt.figure(figsize=(12, 5))
df, fig = exper_med.plot(add_high_value, fig, col=2, percnet=percent, save_output=True)

# %%
fig = plt.figure(figsize=(12, 5))
df, fig = exper_med.plot(add_low_value, fig, col=2, percnet=percent, save_output=True)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
