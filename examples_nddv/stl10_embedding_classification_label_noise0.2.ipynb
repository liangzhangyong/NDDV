# %% [markdown]
# # stl10-embedding dataset

# %%
# Imports
import os
import sys
BASE_DIR = os.path.dirname(os.getcwd())
sys.path.append(BASE_DIR)
import torch
import numpy as np
import pandas as pd

# Opendataval
from dataval.dataloader import Register, DataFetcher, mix_labels, add_gauss_noise
from dataval.datavaluation import NDDV, NDSV
from dataval.experiment import ExperimentMediator

import warnings
warnings.filterwarnings("ignore")
# Out:
# [KeOps] Warning :
#     The default C++ compiler could not be found on your system.
#     You need to either define the CXX environment variable or a symlink to the g++ command.
#     For example if g++-8 is the command you can do
#       import os
#       os.environ['CXX'] = 'g++-8'
#
# [KeOps] Warning : Cuda libraries were not detected on the system ; using cpu only mode

# %%
DataFetcher.datasets_available()
# Out:
# {'2dplanes',
#  'MiniBooNE',
#  'adult',
#  'bbc',
#  'bbc-embeddings',
#  'breast_cancer',
#  'challenge-iris',
#  'cifar10',
#  'cifar10-embeddings',
#  'cifar100',
#  'cifar100-embeddings',
#  'creditcard',
#  'diabetes',
#  'digits',
#  'echoMonths',
#  'election',
#  'electricity',
#  'fashion',
#  'fmnist-embeddings',
#  'fried',
#  'gaussian_classifier',
#  'gaussian_classifier_high_dim',
#  'imdb',
#  'imdb-embeddings',
#  'iris',
#  'linnerud',
#  'lowbwt',
#  'mnist',
#  'mnist-embeddings',
#  'mv',
#  'nomao',
#  'pol',
#  'stl10-embeddings',
#  'stock',
#  'svhn-embeddings',
#  'vehicle_sensIT',
#  'wave_energy',
#  'webdata_wXa'}

# %% [markdown]
# ## [Step 1] Set up an environment
# `ExperimentMediator` is a fundamental concept in establishing the `opendataval` environment. It empowers users to configure hyperparameters, including a dataset, a type of synthetic noise, and a prediction model. With  `ExperimentMediator`, users can effortlessly compute various data valuation algorithms.
#
# The following code cell demonstrates how to set up `ExperimentMediator` with a pre-registered dataset and a prediction model.
# - Dataset: adult
# - Model: sklearn's logistic regression model
# - Metric: Classification accuracy

# %%
dataset_name = "stl10-embeddings"
train_count, valid_count, test_count, meta_count = 1000, 100, 300, 100
# train_count, valid_count, test_count, meta_count = 0.7, 0.05, 0.2, 0.05
noise_rate = 0.2
noise_kwargs = {'noise_rate': noise_rate}
max_epoch = 3
batch_size = 100
lr = 0.01
random_state = 42
train_kwargs = {"epochs": max_epoch, "batch_size": batch_size, "lr": lr}
# model_name = "classifiermlp"   # "sklogreg"
model_name = "LogisticRegression"
metric_name = "accuracy"
cache_dir = "./data_files/"
add_noise = mix_labels
noise_type = "mix_labels"
device = 'cuda' if torch.cuda.is_available() else 'mps' if torch.backends.mps.is_available() else 'cpu'

exper_med = ExperimentMediator.model_factory_setup(
    dataset_name=dataset_name,
    cache_dir=cache_dir,  
    force_download=False,
    train_count=train_count,
    valid_count=valid_count,
    test_count=test_count,
    meta_count=meta_count,
    add_noise=add_noise, 
    noise_kwargs=noise_kwargs,
    train_kwargs=train_kwargs,
    random_state = random_state,
    model_name=model_name,
    metric_name=metric_name,
    device=device
)
# Out:
# 40it [07:29, 11.25s/it]
# Base line model metric_name='accuracy': perf=0.9366666674613953

# %% [markdown]
# A full list of registered datasets can be found [here](https://github.com/opendataval/opendataval/blob/main/opendataval/dataloader/fetcher.py#L121). A list of available  prediction models can be found [here](https://github.com/opendataval/opendataval/blob/main/opendataval/model/__init__.py#L111).

# %% [markdown]
# ## [Step 2] Compute data values
# `opendataval` provides various state-of-the-art data valuation algorithms. `ExperimentMediator.compute_data_values()` computes data values.

# %%
data_evaluators = [NDSV(mfg_epochs=50, base_model=model_name, meta_interval=5, Ntime=1, batch_size=batch_size, weight_decay=5e-4, meta_weight_decay=1e-4, meta_hidden_size=100)]

# %%
# %%time
# compute data values.
exper_med = exper_med.compute_data_values(data_evaluators=data_evaluators)
# Out:
#   2%|▏         | 1/50 [00:01<01:29,  1.83s/it]
# Epoch: 0, Test Accuracy: 12.67%
#   4%|▍         | 2/50 [00:04<01:48,  2.25s/it]
# Epoch: 1, Test Accuracy: 19.00%
#   6%|▌         | 3/50 [00:06<01:41,  2.16s/it]
# Epoch: 2, Test Accuracy: 25.67%
#   8%|▊         | 4/50 [00:08<01:32,  2.02s/it]
# Epoch: 3, Test Accuracy: 34.33%
#  10%|█         | 5/50 [00:10<01:31,  2.04s/it]
# Epoch: 4, Test Accuracy: 42.00%
#  12%|█▏        | 6/50 [00:12<01:26,  1.97s/it]
# Epoch: 5, Test Accuracy: 42.00%
#  14%|█▍        | 7/50 [00:14<01:35,  2.21s/it]
# Epoch: 6, Test Accuracy: 42.67%
#  16%|█▌        | 8/50 [00:16<01:28,  2.11s/it]
# Epoch: 7, Test Accuracy: 43.67%
#  18%|█▊        | 9/50 [00:18<01:25,  2.09s/it]
# Epoch: 8, Test Accuracy: 42.67%
#  20%|██        | 10/50 [00:20<01:20,  2.01s/it]
# Epoch: 9, Test Accuracy: 41.67%
#  22%|██▏       | 11/50 [00:22<01:19,  2.04s/it]
# Epoch: 10, Test Accuracy: 38.67%
#  24%|██▍       | 12/50 [00:25<01:23,  2.21s/it]
# Epoch: 11, Test Accuracy: 39.33%
#  26%|██▌       | 13/50 [00:27<01:21,  2.21s/it]
# Epoch: 12, Test Accuracy: 41.33%
#  28%|██▊       | 14/50 [00:29<01:15,  2.09s/it]
# Epoch: 13, Test Accuracy: 43.00%
#  30%|███       | 15/50 [00:31<01:17,  2.21s/it]
# Epoch: 14, Test Accuracy: 47.00%
#  32%|███▏      | 16/50 [00:34<01:19,  2.35s/it]
# Epoch: 15, Test Accuracy: 48.33%
#  34%|███▍      | 17/50 [00:36<01:15,  2.29s/it]
# Epoch: 16, Test Accuracy: 49.67%
#  36%|███▌      | 18/50 [00:38<01:09,  2.19s/it]
# Epoch: 17, Test Accuracy: 49.00%
#  38%|███▊      | 19/50 [00:40<01:06,  2.15s/it]
# Epoch: 18, Test Accuracy: 49.33%
#  40%|████      | 20/50 [00:42<01:05,  2.17s/it]
# Epoch: 19, Test Accuracy: 51.33%
#  42%|████▏     | 21/50 [00:45<01:02,  2.16s/it]
# Epoch: 20, Test Accuracy: 55.67%
#  44%|████▍     | 22/50 [00:46<00:58,  2.07s/it]
# Epoch: 21, Test Accuracy: 57.33%
#  46%|████▌     | 23/50 [00:48<00:55,  2.07s/it]
# Epoch: 22, Test Accuracy: 58.00%
#  48%|████▊     | 24/50 [00:50<00:52,  2.03s/it]
# Epoch: 23, Test Accuracy: 58.67%
#  50%|█████     | 25/50 [00:53<00:54,  2.19s/it]
# Epoch: 24, Test Accuracy: 58.33%
#  52%|█████▏    | 26/50 [00:55<00:53,  2.24s/it]
# Epoch: 25, Test Accuracy: 58.00%
#  54%|█████▍    | 27/50 [00:57<00:48,  2.11s/it]
# Epoch: 26, Test Accuracy: 58.00%
#  56%|█████▌    | 28/50 [00:59<00:43,  1.98s/it]
# Epoch: 27, Test Accuracy: 63.00%
#  58%|█████▊    | 29/50 [01:01<00:44,  2.11s/it]
# Epoch: 28, Test Accuracy: 64.67%
#  60%|██████    | 30/50 [01:03<00:42,  2.12s/it]
# Epoch: 29, Test Accuracy: 65.00%
#  62%|██████▏   | 31/50 [01:05<00:38,  2.02s/it]
# Epoch: 30, Test Accuracy: 64.67%
#  64%|██████▍   | 32/50 [01:07<00:35,  1.97s/it]
# Epoch: 31, Test Accuracy: 64.67%
#  66%|██████▌   | 33/50 [01:09<00:33,  1.94s/it]
# Epoch: 32, Test Accuracy: 63.67%
#  68%|██████▊   | 34/50 [01:11<00:32,  2.06s/it]
# Epoch: 33, Test Accuracy: 65.33%
#  70%|███████   | 35/50 [01:13<00:31,  2.13s/it]
# Epoch: 34, Test Accuracy: 65.00%
#  72%|███████▏  | 36/50 [01:16<00:30,  2.20s/it]
# Epoch: 35, Test Accuracy: 64.00%
#  74%|███████▍  | 37/50 [01:18<00:28,  2.20s/it]
# Epoch: 36, Test Accuracy: 64.67%
#  76%|███████▌  | 38/50 [01:20<00:25,  2.11s/it]
# Epoch: 37, Test Accuracy: 65.33%
#  78%|███████▊  | 39/50 [01:22<00:22,  2.08s/it]
# Epoch: 38, Test Accuracy: 65.00%
#  80%|████████  | 40/50 [01:24<00:19,  1.97s/it]
# Epoch: 39, Test Accuracy: 63.67%
#  82%|████████▏ | 41/50 [01:25<00:17,  1.93s/it]
# Epoch: 40, Test Accuracy: 64.00%
#  84%|████████▍ | 42/50 [01:27<00:15,  1.94s/it]
# Epoch: 41, Test Accuracy: 63.00%
#  86%|████████▌ | 43/50 [01:30<00:14,  2.05s/it]
# Epoch: 42, Test Accuracy: 64.67%
#  88%|████████▊ | 44/50 [01:32<00:12,  2.07s/it]
# Epoch: 43, Test Accuracy: 64.00%
#  90%|█████████ | 45/50 [01:34<00:09,  1.95s/it]
# Epoch: 44, Test Accuracy: 64.33%
#  92%|█████████▏| 46/50 [01:35<00:07,  1.86s/it]
# Epoch: 45, Test Accuracy: 64.67%
#  94%|█████████▍| 47/50 [01:37<00:05,  1.79s/it]
# Epoch: 46, Test Accuracy: 64.67%
#  96%|█████████▌| 48/50 [01:39<00:03,  1.95s/it]
# Epoch: 47, Test Accuracy: 64.67%
#  98%|█████████▊| 49/50 [01:41<00:01,  1.90s/it]
# Epoch: 48, Test Accuracy: 64.33%
# 100%|██████████| 50/50 [01:42<00:00,  2.06s/it]
# Epoch: 49, Test Accuracy: 64.33%
# Elapsed time NDSV(mfg_epochs=50, base_model=LogisticRegression, meta_interval=5, Ntime=1, batch_size=100, weight_decay=0.0005, meta_weight_decay=0.0001, meta_hidden_size=100): 0:01:42.989002
# CPU times: total: 2min 37s
# Wall time: 1min 42s

# %% [markdown]
# ## [Step 3] Evaluate data values

# %%
from dataval.experiment.exper_methods import (
    discover_corrupted_sample,
    noisy_detection,
    remove_high_low,
    remove_high_value,
    remove_low_value,
    add_low_high,
    add_high_value,
    add_low_value,
    save_dataval
)
from matplotlib import pyplot as plt

# %%
# Saving the results with percent 5%
percent = 0.05
output_dir = f"../results/NDDV_{device}_{dataset_name}_{model_name}_{noise_type}_{noise_rate=}_{train_count=}_{percent=}/"
exper_med.set_output_directory(output_dir)
output_dir
# Out:
# '../results/NDDV_cpu_stl10-embeddings_LogisticRegression_mix_labels_noise_rate=0.2_train_count=1000_percent=0.05/'

# %% [markdown]
# ### Noisy data detection
# - `noisy_detection` performs the noisy data detection task and evaluates the F1-score of each data valuation algorithm's prediction. The higher, the better.
#   - noisy data: mislabeled data

# %%
exper_med.evaluate(noisy_detection, save_output=True)
# Out:
#                                                     kmeans_f1
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...   0.757576

# %% [markdown]
# ### Discover noisy samples
# - `discover_corrupted_sample` visualizes how well noisy data points are identified when a fraction of dataset is inspected.

# %%
fig = plt.figure(figsize=(18, 8))
df, fig = exper_med.plot(discover_corrupted_sample, fig, col=2, percnet=percent, save_output=True)

# %% [markdown]
# ### Point removal experiment
# - `remove_high_low` performs the point removal experiment. Each data valution algorithm, it provides two curves: one is removing data in a descending order (orange), the other is in an ascending order (blue). As for the orange (resp. blue) curve, the lower (resp. upper), the better.

# %%
fig = plt.figure(figsize=(18, 8))
df_resp, fig = exper_med.plot(remove_high_low, fig, col=2, percnet=percent, save_output=True)

# %%
fig = plt.figure(figsize=(18, 8))
df, fig = exper_med.plot(remove_high_value, fig, col=2, percnet=percent, save_output=True)

# %%
fig = plt.figure(figsize=(18, 8))
df, fig = exper_med.plot(remove_low_value, fig, col=2, percnet=percent, save_output=True)

# %%
df_resp # it provides complete information for generating point-removal experiment figures.
# Out:
#                                                    remove_least_influential_first_Metrics.ACCURACY  \
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                        0.916667
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                        0.933333
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                            0.93
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                            0.92
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                        0.913333
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                        0.916667
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                        0.743333
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                            0.73
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                            0.61
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                             0.6
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                             0.5
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                            0.42
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                        0.366667
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                        0.146667
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                            0.23
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                        0.206667
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                            0.23
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                        0.233333
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                        0.206667
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                        0.113333
#
#                                                    remove_most_influential_first_Metrics.ACCURACY  \
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                       0.923333
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                       0.923333
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                           0.91
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                           0.92
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                           0.91
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                           0.88
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                       0.713333
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                           0.62
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                       0.526667
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                       0.503333
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                       0.216667
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                       0.126667
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                           0.29
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                       0.173333
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                       0.166667
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                       0.173333
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                       0.166667
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                       0.056667
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                            0.0
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                           0.09
#
#                                                     axis
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...   0.0
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...  0.05
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...   0.1
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...  0.15
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...   0.2
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...  0.25
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...   0.3
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...  0.35
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...   0.4
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...  0.45
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...   0.5
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...  0.55
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...   0.6
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...  0.65
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...   0.7
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...  0.75
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...   0.8
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...  0.85
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...   0.9
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...  0.95

# %%
fig = plt.figure(figsize=(18, 8))
df_addp, fig = exper_med.plot(add_low_high, fig, col=2, percnet=percent, save_output=True)

# %%
fig = plt.figure(figsize=(18, 8))
df, fig = exper_med.plot(add_high_value, fig, col=2, percnet=percent, save_output=True)

# %%
fig = plt.figure(figsize=(18, 8))
df, fig = exper_med.plot(add_low_value, fig, col=2, percnet=percent, save_output=True)

# %%
df_addp
# Out:
#                                                    add_least_influential_first_Metrics.ACCURACY  \
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                          0.0
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                     0.056667
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                     0.143333
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                     0.176667
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                     0.143333
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                     0.173333
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                     0.173333
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                         0.24
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                     0.293333
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                         0.52
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                     0.553333
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                     0.653333
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                     0.736667
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                     0.866667
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                         0.92
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                         0.94
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                     0.923333
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                         0.95
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                         0.94
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                     0.933333
#
#                                                    add_most_influential_first_Metrics.ACCURACY  \
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                    0.936667
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                    0.943333
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                    0.923333
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                    0.936667
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                        0.93
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                    0.926667
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                    0.926667
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                    0.916667
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                    0.933333
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                    0.933333
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                        0.94
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                        0.93
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                    0.926667
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                    0.893333
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                    0.923333
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                    0.933333
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                    0.943333
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                    0.933333
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                    0.913333
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                    0.936667
#
#                                                     axis
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...  0.95
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...   0.9
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...  0.85
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...   0.8
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...  0.75
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...   0.7
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...  0.65
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...   0.6
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...  0.55
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...   0.5
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...  0.45
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...   0.4
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...  0.35
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...   0.3
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...  0.25
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...   0.2
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...  0.15
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...   0.1
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...  0.05
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...   0.0

# %% [markdown]
# ### Save data values
# - `save_dataval` stores computed data values at `{output_dir}/save_dataval.csv`.

# %%
exper_med.evaluate(save_dataval, save_output=True)
# Out:
#                                                    indices data_values
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...    4657   -0.000395
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...    3539    0.000307
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...     907    0.000131
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...    4353    0.000169
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...    3745    0.000307
# ...                                                    ...         ...
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...    3589    0.000307
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...     679    0.000307
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...    3999    0.000297
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...    2706   -0.000694
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...    1128    0.000307
#
# [1000 rows x 2 columns]

# %% [markdown]
# ### percent is 0.1

# %%
# Saving the results with percent 10%
percent = 0.1
output_dir = f"../results/NDDV_{device}_{dataset_name}_{model_name}_{noise_type}_{noise_rate=}_{train_count=}_{percent=}/"
exper_med.set_output_directory(output_dir)
output_dir
# Out:
# '../results/NDDV_cpu_stl10-embeddings_LogisticRegression_mix_labels_noise_rate=0.2_train_count=1000_percent=0.1/'

# %%
exper_med.evaluate(noisy_detection, save_output=True)
# Out:
#                                                     kmeans_f1
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...   0.757576

# %%
fig = plt.figure(figsize=(18, 8))
df, fig = exper_med.plot(discover_corrupted_sample, fig, col=2, percnet=percent, save_output=True)

# %%
fig = plt.figure(figsize=(18, 8))
df_resp, fig = exper_med.plot(remove_high_low, fig, col=2, percnet=percent, save_output=True)

# %%
fig = plt.figure(figsize=(18, 8))
df, fig = exper_med.plot(remove_high_value, fig, col=2, percnet=percent, save_output=True)

# %%
fig = plt.figure(figsize=(18, 8))
df, fig = exper_med.plot(remove_low_value, fig, col=2, percnet=percent, save_output=True)

# %%
fig = plt.figure(figsize=(18, 8))
df_resp, fig = exper_med.plot(add_low_high, fig, col=2, percnet=percent, save_output=True)

# %%
fig = plt.figure(figsize=(18, 8))
df, fig = exper_med.plot(add_high_value, fig, col=2, percnet=percent, save_output=True)

# %%
fig = plt.figure(figsize=(18, 8))
df, fig = exper_med.plot(add_low_value, fig, col=2, percnet=percent, save_output=True)
