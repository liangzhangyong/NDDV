# %% [markdown]
# # imdb-embedding dataset

# %%
# Imports
import os
import sys
BASE_DIR = os.path.dirname(os.getcwd())
sys.path.append(BASE_DIR)
import torch
import numpy as np
import pandas as pd

# Opendataval
from dataval.dataloader import Register, DataFetcher, mix_labels, add_gauss_noise
from dataval.datavaluation import NDDV, NDSV
from dataval.experiment import ExperimentMediator

import warnings
warnings.filterwarnings("ignore")
# Out:
# [KeOps] Warning :
#     The default C++ compiler could not be found on your system.
#     You need to either define the CXX environment variable or a symlink to the g++ command.
#     For example if g++-8 is the command you can do
#       import os
#       os.environ['CXX'] = 'g++-8'
#
# [KeOps] Warning : Cuda libraries were not detected on the system ; using cpu only mode

# %%
DataFetcher.datasets_available()
# Out:
# {'2dplanes',
#  'MiniBooNE',
#  'adult',
#  'bbc',
#  'bbc-embeddings',
#  'breast_cancer',
#  'challenge-iris',
#  'cifar10',
#  'cifar10-embeddings',
#  'cifar100',
#  'cifar100-embeddings',
#  'creditcard',
#  'diabetes',
#  'digits',
#  'echoMonths',
#  'election',
#  'electricity',
#  'fashion',
#  'fmnist-embeddings',
#  'fried',
#  'gaussian_classifier',
#  'gaussian_classifier_high_dim',
#  'imdb',
#  'imdb-embeddings',
#  'iris',
#  'linnerud',
#  'lowbwt',
#  'mnist',
#  'mnist-embeddings',
#  'mv',
#  'nomao',
#  'pol',
#  'stl10-embeddings',
#  'stock',
#  'svhn-embeddings',
#  'vehicle_sensIT',
#  'wave_energy',
#  'webdata_wXa'}

# %% [markdown]
# ## [Step 1] Set up an environment
# `ExperimentMediator` is a fundamental concept in establishing the `opendataval` environment. It empowers users to configure hyperparameters, including a dataset, a type of synthetic noise, and a prediction model. With  `ExperimentMediator`, users can effortlessly compute various data valuation algorithms.
#
# The following code cell demonstrates how to set up `ExperimentMediator` with a pre-registered dataset and a prediction model.
# - Dataset: adult
# - Model: sklearn's logistic regression model
# - Metric: Classification accuracy

# %%
dataset_name = "imdb-embeddings"
train_count, valid_count, test_count, meta_count = 1000, 100, 300, 100
noise_rate = 0.1
noise_kwargs = {'noise_rate': noise_rate}
max_epoch = 3
batch_size = 32
lr = 0.01
random_state = 42
train_kwargs = {"epochs": max_epoch, "batch_size": batch_size, "lr": lr}
model_name = "classifiermlp"   # "sklogreg"
# model_name = "LogisticRegression"
metric_name = "accuracy"
cache_dir = "../data_files/"
add_noise = mix_labels
noise_type = "mix_labels"
# device = 'cpu'
device = 'cuda:1' if torch.cuda.is_available() else 'mps' if torch.backends.mps.is_available() else 'cpu'

exper_med = ExperimentMediator.model_factory_setup(
    dataset_name=dataset_name,
    cache_dir=cache_dir,  
    force_download=False,
    train_count=train_count,
    valid_count=valid_count,
    test_count=test_count,
    meta_count=meta_count,
    add_noise=add_noise, 
    noise_kwargs=noise_kwargs,
    train_kwargs=train_kwargs,
    random_state = random_state,
    model_name=model_name,
    metric_name=metric_name,
    device=device
)
# Out:
# Base line model metric_name='accuracy': perf=0.4933333396911621

# %% [markdown]
# A full list of registered datasets can be found [here](https://github.com/opendataval/opendataval/blob/main/opendataval/dataloader/fetcher.py#L121). A list of available  prediction models can be found [here](https://github.com/opendataval/opendataval/blob/main/opendataval/model/__init__.py#L111).

# %% [markdown]
# ## [Step 2] Compute data values
# `opendataval` provides various state-of-the-art data valuation algorithms. `ExperimentMediator.compute_data_values()` computes data values.

# %%
data_evaluators = [NDSV(mfg_epochs=50, base_model=model_name, meta_interval=5, Ntime=4, batch_size=batch_size, weight_decay=1e-4, meta_weight_decay=0, meta_hidden_size=10)]

# %%
# %%time
# compute data values.
exper_med = exper_med.compute_data_values(data_evaluators=data_evaluators)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:01<01:27,  1.78s/it]
# Epoch: 0, Test Accuracy: 60.33%
#   4%|▍         | 2/50 [00:03<01:16,  1.59s/it]
# Epoch: 1, Test Accuracy: 76.67%
#   6%|▌         | 3/50 [00:04<01:12,  1.54s/it]
# Epoch: 2, Test Accuracy: 69.33%
#   8%|▊         | 4/50 [00:06<01:09,  1.51s/it]
# Epoch: 3, Test Accuracy: 68.33%
#  10%|█         | 5/50 [00:07<01:06,  1.48s/it]
# Epoch: 4, Test Accuracy: 76.33%
#  12%|█▏        | 6/50 [00:09<01:04,  1.46s/it]
# Epoch: 5, Test Accuracy: 72.33%
#  14%|█▍        | 7/50 [00:10<01:02,  1.46s/it]
# Epoch: 6, Test Accuracy: 69.00%
#  16%|█▌        | 8/50 [00:11<01:00,  1.44s/it]
# Epoch: 7, Test Accuracy: 70.00%
#  18%|█▊        | 9/50 [00:13<00:59,  1.44s/it]
# Epoch: 8, Test Accuracy: 70.00%
#  20%|██        | 10/50 [00:14<00:59,  1.48s/it]
# Epoch: 9, Test Accuracy: 64.00%
#  22%|██▏       | 11/50 [00:16<00:58,  1.50s/it]
# Epoch: 10, Test Accuracy: 69.00%
#  24%|██▍       | 12/50 [00:18<00:57,  1.52s/it]
# Epoch: 11, Test Accuracy: 69.33%
#  26%|██▌       | 13/50 [00:19<00:55,  1.51s/it]
# Epoch: 12, Test Accuracy: 69.67%
#  28%|██▊       | 14/50 [00:21<00:54,  1.51s/it]
# Epoch: 13, Test Accuracy: 75.33%
#  30%|███       | 15/50 [00:22<00:55,  1.58s/it]
# Epoch: 14, Test Accuracy: 67.67%
#  32%|███▏      | 16/50 [00:24<00:53,  1.59s/it]
# Epoch: 15, Test Accuracy: 59.33%
#  34%|███▍      | 17/50 [00:25<00:51,  1.56s/it]
# Epoch: 16, Test Accuracy: 74.33%
#  36%|███▌      | 18/50 [00:27<00:50,  1.57s/it]
# Epoch: 17, Test Accuracy: 70.33%
#  38%|███▊      | 19/50 [00:28<00:48,  1.56s/it]
# Epoch: 18, Test Accuracy: 57.33%
#  40%|████      | 20/50 [00:30<00:46,  1.54s/it]
# Epoch: 19, Test Accuracy: 74.33%
#  42%|████▏     | 21/50 [00:32<00:44,  1.55s/it]
# Epoch: 20, Test Accuracy: 71.67%
#  44%|████▍     | 22/50 [00:33<00:42,  1.52s/it]
# Epoch: 21, Test Accuracy: 63.00%
#  46%|████▌     | 23/50 [00:34<00:40,  1.49s/it]
# Epoch: 22, Test Accuracy: 68.33%
#  48%|████▊     | 24/50 [00:36<00:38,  1.48s/it]
# Epoch: 23, Test Accuracy: 66.33%
#  50%|█████     | 25/50 [00:37<00:36,  1.47s/it]
# Epoch: 24, Test Accuracy: 70.33%
#  52%|█████▏    | 26/50 [00:39<00:35,  1.48s/it]
# Epoch: 25, Test Accuracy: 70.67%
#  54%|█████▍    | 27/50 [00:40<00:34,  1.50s/it]
# Epoch: 26, Test Accuracy: 73.67%
#  56%|█████▌    | 28/50 [00:42<00:36,  1.65s/it]
# Epoch: 27, Test Accuracy: 66.67%
#  58%|█████▊    | 29/50 [00:44<00:34,  1.64s/it]
# Epoch: 28, Test Accuracy: 68.33%
#  60%|██████    | 30/50 [00:46<00:32,  1.65s/it]
# Epoch: 29, Test Accuracy: 73.00%
#  62%|██████▏   | 31/50 [00:47<00:31,  1.67s/it]
# Epoch: 30, Test Accuracy: 75.67%
#  64%|██████▍   | 32/50 [00:49<00:30,  1.68s/it]
# Epoch: 31, Test Accuracy: 73.67%
#  66%|██████▌   | 33/50 [00:51<00:27,  1.63s/it]
# Epoch: 32, Test Accuracy: 71.00%
#  68%|██████▊   | 34/50 [00:52<00:24,  1.56s/it]
# Epoch: 33, Test Accuracy: 72.67%
#  70%|███████   | 35/50 [00:53<00:22,  1.53s/it]
# Epoch: 34, Test Accuracy: 72.67%
#  72%|███████▏  | 36/50 [00:55<00:20,  1.50s/it]
# Epoch: 35, Test Accuracy: 73.00%
#  74%|███████▍  | 37/50 [00:57<00:21,  1.65s/it]
# Epoch: 36, Test Accuracy: 78.33%
#  76%|███████▌  | 38/50 [00:58<00:19,  1.60s/it]
# Epoch: 37, Test Accuracy: 77.33%
#  78%|███████▊  | 39/50 [01:00<00:17,  1.58s/it]
# Epoch: 38, Test Accuracy: 76.00%
#  80%|████████  | 40/50 [01:01<00:15,  1.56s/it]
# Epoch: 39, Test Accuracy: 75.00%
#  82%|████████▏ | 41/50 [01:03<00:13,  1.55s/it]
# Epoch: 40, Test Accuracy: 76.67%
#  84%|████████▍ | 42/50 [01:04<00:12,  1.53s/it]
# Epoch: 41, Test Accuracy: 76.33%
#  86%|████████▌ | 43/50 [01:06<00:10,  1.50s/it]
# Epoch: 42, Test Accuracy: 74.33%
#  88%|████████▊ | 44/50 [01:07<00:08,  1.49s/it]
# Epoch: 43, Test Accuracy: 75.33%
#  90%|█████████ | 45/50 [01:09<00:07,  1.48s/it]
# Epoch: 44, Test Accuracy: 76.00%
#  92%|█████████▏| 46/50 [01:10<00:05,  1.47s/it]
# Epoch: 45, Test Accuracy: 77.00%
#  94%|█████████▍| 47/50 [01:12<00:04,  1.51s/it]
# Epoch: 46, Test Accuracy: 76.33%
#  96%|█████████▌| 48/50 [01:14<00:03,  1.58s/it]
# Epoch: 47, Test Accuracy: 77.33%
#  98%|█████████▊| 49/50 [01:15<00:01,  1.57s/it]
# Epoch: 48, Test Accuracy: 76.67%
# 100%|██████████| 50/50 [01:17<00:00,  1.54s/it]
# Epoch: 49, Test Accuracy: 77.00%
# Elapsed time NDSV(mfg_epochs=50, base_model=classifiermlp, meta_interval=5, Ntime=3, batch_size=32, weight_decay=0.0001, meta_weight_decay=0, meta_hidden_size=10): 0:01:17.328673
# CPU times: user 36min 24s, sys: 27 s, total: 36min 51s
# Wall time: 1min 17s

# %% [markdown]
# ## [Step 3] Evaluate data values

# %%
from dataval.experiment.exper_methods import (
    discover_corrupted_sample,
    noisy_detection,
    remove_high_low,
    remove_high_value,
    remove_low_value,
    add_low_high,
    add_high_value,
    add_low_value,
    save_dataval
)
from matplotlib import pyplot as plt

# %%
# Saving the results with percent 5%
percent = 0.05
output_dir = f"../results/NDDV_{device}_{dataset_name}_{model_name}_{noise_type}_{noise_rate=}_{train_count=}_{percent=}/"
exper_med.set_output_directory(output_dir)
output_dir
# Out:
# '../results/NDDV_cuda:1_imdb-embeddings_classifiermlp_mix_labels_noise_rate=0.1_train_count=1000_percent=0.05/'

# %% [markdown]
# ### Noisy data detection
# - `noisy_detection` performs the noisy data detection task and evaluates the F1-score of each data valuation algorithm's prediction. The higher, the better.
#   - noisy data: mislabeled data

# %%
exper_med.evaluate(noisy_detection, save_output=True)
# Out:
#                                                     kmeans_f1
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.265625

# %% [markdown]
# ### Discover noisy samples
# - `discover_corrupted_sample` visualizes how well noisy data points are identified when a fraction of dataset is inspected.

# %%
fig = plt.figure(figsize=(18, 8))
df, fig = exper_med.plot(discover_corrupted_sample, fig, col=2, percnet=percent, save_output=True)

# %% [markdown]
# ### Point removal experiment
# - `remove_high_low` performs the point removal experiment. Each data valution algorithm, it provides two curves: one is removing data in a descending order (orange), the other is in an ascending order (blue). As for the orange (resp. blue) curve, the lower (resp. upper), the better.

# %%
fig = plt.figure(figsize=(18, 8))
df_resp, fig = exper_med.plot(remove_high_low, fig, col=2, percnet=percent, save_output=True)

# %%
fig = plt.figure(figsize=(18, 8))
df, fig = exper_med.plot(remove_high_value, fig, col=2, percnet=percent, save_output=True)

# %%
fig = plt.figure(figsize=(18, 8))
df, fig = exper_med.plot(remove_low_value, fig, col=2, percnet=percent, save_output=True)

# %%
df_resp # it provides complete information for generating point-removal experiment figures.
# Out:
#                                                    remove_least_influential_first_Metrics.ACCURACY  \
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                            0.82
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                        0.823333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                        0.783333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                        0.813333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                        0.833333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                        0.806667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                             0.8
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                        0.806667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                            0.77
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                            0.83
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                        0.813333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                        0.626667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                        0.526667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                        0.806667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                            0.75
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                        0.526667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                        0.526667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                        0.526667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                        0.526667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                        0.526667
#
#                                                    remove_most_influential_first_Metrics.ACCURACY  \
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                       0.826667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                       0.586667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                       0.803333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                       0.473333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                       0.473333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                       0.473333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                       0.473333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                       0.653333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                       0.473333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                       0.473333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                       0.473333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                       0.473333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                       0.473333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                       0.473333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                       0.473333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                           0.46
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                       0.473333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                       0.473333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                       0.473333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                       0.473333
#
#                                                     axis
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.0
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...  0.05
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.1
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...  0.15
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.2
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...  0.25
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.3
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...  0.35
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.4
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...  0.45
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.5
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...  0.55
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.6
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...  0.65
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.7
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...  0.75
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.8
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...  0.85
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.9
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...  0.95

# %%
fig = plt.figure(figsize=(18, 8))
df_addp, fig = exper_med.plot(add_low_high, fig, col=2, percnet=percent, save_output=True)

# %%
fig = plt.figure(figsize=(18, 8))
df, fig = exper_med.plot(add_high_value, fig, col=2, percnet=percent, save_output=True)

# %%
fig = plt.figure(figsize=(18, 8))
df, fig = exper_med.plot(add_low_value, fig, col=2, percnet=percent, save_output=True)

# %%
df_addp
# Out:
#                                                    add_least_influential_first_Metrics.ACCURACY  \
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                     0.473333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                     0.473333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                     0.473333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                     0.473333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                     0.473333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                     0.473333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                     0.473333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                     0.473333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                     0.473333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                     0.473333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                     0.473333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                     0.473333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                     0.473333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                     0.473333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                     0.473333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                     0.473333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                     0.766667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                         0.77
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                         0.75
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                     0.763333
#
#                                                    add_most_influential_first_Metrics.ACCURACY  \
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                    0.783333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                        0.81
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                    0.773333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                    0.816667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                    0.836667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                    0.803333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                    0.836667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                    0.793333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                        0.83
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                    0.736667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                    0.803333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                    0.753333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                         0.8
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                         0.8
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                    0.756667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                    0.766667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                    0.803333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                    0.746667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                        0.82
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                        0.81
#
#                                                     axis
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...  0.95
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.9
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...  0.85
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.8
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...  0.75
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.7
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...  0.65
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.6
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...  0.55
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.5
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...  0.45
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.4
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...  0.35
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.3
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...  0.25
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.2
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...  0.15
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.1
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...  0.05
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.0

# %% [markdown]
# ### Save data values
# - `save_dataval` stores computed data values at `{output_dir}/save_dataval.csv`.

# %%
exper_med.evaluate(save_dataval, save_output=True)
# Out:
#                                                    indices data_values
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   25285    0.002825
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   27284    0.006666
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...    3792   -0.002257
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   31861     0.00499
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   45344    0.005219
# ...                                                    ...         ...
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   23751    0.016294
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   40009    0.028517
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...    5987   -0.002524
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   28751    0.023648
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   13862    0.015259
#
# [1000 rows x 2 columns]

# %% [markdown]
# ### percent is 0.1

# %%
# Saving the results with percent 10%
percent = 0.1
output_dir = f"../results/NDDV_{device}_{dataset_name}_{model_name}_{noise_type}_{noise_rate=}_{train_count=}_{percent=}/"
exper_med.set_output_directory(output_dir)
output_dir
# Out:
# '../results/NDDV_cuda:1_imdb-embeddings_classifiermlp_mix_labels_noise_rate=0.1_train_count=1000_percent=0.1/'

# %%
exper_med.evaluate(noisy_detection, save_output=True)
# Out:
#                                                     kmeans_f1
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.265625

# %%
fig = plt.figure(figsize=(18, 8))
df, fig = exper_med.plot(discover_corrupted_sample, fig, col=2, percnet=percent, save_output=True)

# %%
fig = plt.figure(figsize=(18, 8))
df_resp, fig = exper_med.plot(remove_high_low, fig, col=2, percnet=percent, save_output=True)

# %%
fig = plt.figure(figsize=(18, 8))
df, fig = exper_med.plot(remove_high_value, fig, col=2, percnet=percent, save_output=True)

# %%
fig = plt.figure(figsize=(18, 8))
df, fig = exper_med.plot(remove_low_value, fig, col=2, percnet=percent, save_output=True)

# %%
fig = plt.figure(figsize=(18, 8))
df_resp, fig = exper_med.plot(add_low_high, fig, col=2, percnet=percent, save_output=True)

# %%
fig = plt.figure(figsize=(18, 8))
df, fig = exper_med.plot(add_high_value, fig, col=2, percnet=percent, save_output=True)

# %%
fig = plt.figure(figsize=(18, 8))
df, fig = exper_med.plot(add_low_value, fig, col=2, percnet=percent, save_output=True)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
