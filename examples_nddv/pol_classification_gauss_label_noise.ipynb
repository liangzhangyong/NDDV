# %% [markdown]
# # pol dataset

# %%
# Imports
import os
import sys
BASE_DIR = os.path.dirname(os.getcwd())
sys.path.append(BASE_DIR)
import torch
import numpy as np
import pandas as pd

# Opendataval
from dataval.dataloader import Register, DataFetcher, gauss_labels
from dataval.datavaluation import NDDV, NDSV
from dataval.experiment import ExperimentMediator

import warnings
warnings.filterwarnings("ignore")
# Out:
# [KeOps] Compiling cuda jit compiler engine ...
# [KeOps] Warning : There were warnings or errors compiling formula :
# In file included from /home/kunyu/anaconda3/envs/zyliang/lib/python3.10/site-packages/keopscore/binders/nvrtc/nvrtc_jit.cpp:21:
# /home/kunyu/anaconda3/envs/zyliang/lib/python3.10/site-packages/keopscore/binders/nvrtc/nvrtc_jit.cpp: In function ‘int Compile(const char*, const char*, int, int, const char*)’:
# <command-line>: error: ‘nvrtcGetCUBINSize’ was not declared in this scope; did you mean ‘nvrtcGetPTXSize’?
# /home/kunyu/anaconda3/envs/zyliang/lib/python3.10/site-packages/keopscore/include/utils_pe.h:6:26: note: in definition of macro ‘NVRTC_SAFE_CALL’
#     6 |     nvrtcResult result = x;                                       \
#       |                          ^
# /home/kunyu/anaconda3/envs/zyliang/lib/python3.10/site-packages/keopscore/binders/nvrtc/nvrtc_jit.cpp:90:21: note: in expansion of macro ‘nvrtcGetTARGETSize’
#    90 |     NVRTC_SAFE_CALL(nvrtcGetTARGETSize(prog, &targetSize));
#       |                     ^~~~~~~~~~~~~~~~~~
# <command-line>: error: ‘nvrtcGetCUBIN’ was not declared in this scope; did you mean ‘nvrtcGetPTX’?
# /home/kunyu/anaconda3/envs/zyliang/lib/python3.10/site-packages/keopscore/include/utils_pe.h:6:26: note: in definition of macro ‘NVRTC_SAFE_CALL’
#     6 |     nvrtcResult result = x;                                       \
#       |                          ^
# /home/kunyu/anaconda3/envs/zyliang/lib/python3.10/site-packages/keopscore/binders/nvrtc/nvrtc_jit.cpp:93:21: note: in expansion of macro ‘nvrtcGetTARGET’
#    93 |     NVRTC_SAFE_CALL(nvrtcGetTARGET(prog, target));
#       |                     ^~~~~~~~~~~~~~
#
# OK

# %%
DataFetcher.datasets_available()
# Out:
# {'2dplanes',
#  'MiniBooNE',
#  'adult',
#  'bbc',
#  'bbc-embeddings',
#  'breast_cancer',
#  'challenge-iris',
#  'cifar10',
#  'cifar10-embeddings',
#  'cifar100',
#  'cifar100-embeddings',
#  'creditcard',
#  'diabetes',
#  'digits',
#  'echoMonths',
#  'election',
#  'electricity',
#  'fashion',
#  'fmnist-embeddings',
#  'fried',
#  'gaussian_classifier',
#  'gaussian_classifier_high_dim',
#  'imdb',
#  'imdb-embeddings',
#  'iris',
#  'linnerud',
#  'lowbwt',
#  'mnist',
#  'mnist-embeddings',
#  'mv',
#  'nomao',
#  'pol',
#  'stl10-embeddings',
#  'stock',
#  'svhn-embeddings',
#  'vehicle_sensIT',
#  'wave_energy',
#  'webdata_wXa'}

# %% [markdown]
# ## [Step 1] Set up an environment
# `ExperimentMediator` is a fundamental concept in establishing the `opendataval` environment. It empowers users to configure hyperparameters, including a dataset, a type of synthetic noise, and a prediction model. With  `ExperimentMediator`, users can effortlessly compute various data valuation algorithms.
#
# The following code cell demonstrates how to set up `ExperimentMediator` with a pre-registered dataset and a prediction model.
# - Dataset: adult
# - Model: sklearn's logistic regression model
# - Metric: Classification accuracy

# %%
dataset_name = "pol"
train_count, valid_count, test_count, meta_count = 1000, 100, 300, 100
noise_rate = 0.45
noise_kwargs = {'noise_rate': noise_rate}
max_epoch = 3
batch_size = 32
lr = 0.01
random_state = 42
train_kwargs = {"epochs": max_epoch, "batch_size": batch_size, "lr": lr}
# model_name = "classifiermlp"   # "sklogreg"
model_name = "LogisticRegression"
metric_name = "accuracy"
cache_dir = "../data_files/"
add_noise = gauss_labels
noise_type = "gauss_labels"
device = 'cpu'

exper_med = ExperimentMediator.model_factory_setup(
    dataset_name=dataset_name,
    cache_dir=cache_dir,  
    force_download=False,
    train_count=train_count,
    valid_count=valid_count,
    test_count=test_count,
    meta_count=meta_count,
    add_noise=add_noise, 
    noise_kwargs=noise_kwargs,
    train_kwargs=train_kwargs,
    random_state = random_state,
    model_name=model_name,
    metric_name=metric_name,
    device=device
)
# Out:
# Base line model metric_name='accuracy': perf=0.8700000047683716

# %% [markdown]
# A full list of registered datasets can be found [here](https://github.com/opendataval/opendataval/blob/main/opendataval/dataloader/fetcher.py#L121). A list of available  prediction models can be found [here](https://github.com/opendataval/opendataval/blob/main/opendataval/model/__init__.py#L111).

# %% [markdown]
# ## [Step 2] Compute data values
# `opendataval` provides various state-of-the-art data valuation algorithms. `ExperimentMediator.compute_data_values()` computes data values.

# %%
#0.3 -- 0.784
# data_evaluators = [NDSV(mfg_epochs=50, base_model=model_name, meta_interval=3, Ntime=3, batch_size=batch_size, weight_decay=3e-4, meta_weight_decay=1e-5, meta_hidden_size=10)]

# 0.1 -- 0.75
data_evaluators = [NDSV(mfg_epochs=50, base_model=model_name, meta_interval=4, Ntime=5, batch_size=batch_size, weight_decay=5e-4, meta_weight_decay=1e-5, meta_hidden_size=10)]

# 0.45 -- 0.674
# data_evaluators = [NDSV(mfg_epochs=50, base_model=model_name, meta_interval=3, Ntime=3, batch_size=batch_size, weight_decay=3e-4, meta_weight_decay=1e-5, meta_hidden_size=10)]

# 0.4 -- 0.736
# data_evaluators = [NDSV(mfg_epochs=50, base_model=model_name, meta_interval=3, Ntime=3, batch_size=batch_size, weight_decay=5e-4, meta_weight_decay=1e-5, meta_hidden_size=10)]

# 0.2 -- 0.756
# data_evaluators = [NDSV(mfg_epochs=50, base_model=model_name, meta_interval=3, Ntime=3, batch_size=batch_size, weight_decay=1e-4, meta_weight_decay=1e-5, meta_hidden_size=10)]

# %%
# %%time
# compute data values.
exper_med = exper_med.compute_data_values(data_evaluators=data_evaluators)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:42,  1.16it/s]
# Epoch: 0, Test Accuracy: 60.67%
#   4%|▍         | 2/50 [00:01<00:40,  1.18it/s]
# Epoch: 1, Test Accuracy: 71.00%
#   6%|▌         | 3/50 [00:02<00:39,  1.18it/s]
# Epoch: 2, Test Accuracy: 77.00%
#   8%|▊         | 4/50 [00:03<00:38,  1.18it/s]
# Epoch: 3, Test Accuracy: 88.33%
#  10%|█         | 5/50 [00:04<00:38,  1.18it/s]
# Epoch: 4, Test Accuracy: 82.00%
#  12%|█▏        | 6/50 [00:05<00:37,  1.18it/s]
# Epoch: 5, Test Accuracy: 79.33%
#  14%|█▍        | 7/50 [00:05<00:35,  1.21it/s]
# Epoch: 6, Test Accuracy: 82.00%
#  16%|█▌        | 8/50 [00:06<00:36,  1.16it/s]
# Epoch: 7, Test Accuracy: 82.67%
#  18%|█▊        | 9/50 [00:07<00:33,  1.21it/s]
# Epoch: 8, Test Accuracy: 84.33%
#  20%|██        | 10/50 [00:08<00:32,  1.24it/s]
# Epoch: 9, Test Accuracy: 80.67%
#  22%|██▏       | 11/50 [00:09<00:30,  1.27it/s]
# Epoch: 10, Test Accuracy: 77.67%
#  24%|██▍       | 12/50 [00:09<00:29,  1.29it/s]
# Epoch: 11, Test Accuracy: 82.67%
#  26%|██▌       | 13/50 [00:10<00:28,  1.30it/s]
# Epoch: 12, Test Accuracy: 81.33%
#  28%|██▊       | 14/50 [00:11<00:27,  1.31it/s]
# Epoch: 13, Test Accuracy: 69.67%
#  30%|███       | 15/50 [00:12<00:26,  1.32it/s]
# Epoch: 14, Test Accuracy: 74.33%
#  92%|█████████▏| 46/50 [00:35<00:03,  1.32it/s]
# Epoch: 45, Test Accuracy: 62.67%
#  94%|█████████▍| 47/50 [00:36<00:02,  1.31it/s]
# Epoch: 46, Test Accuracy: 61.67%
#  96%|█████████▌| 48/50 [00:37<00:01,  1.31it/s]
# Epoch: 47, Test Accuracy: 53.00%
#  98%|█████████▊| 49/50 [00:37<00:00,  1.30it/s]
# Epoch: 48, Test Accuracy: 57.67%
# 100%|██████████| 50/50 [00:38<00:00,  1.29it/s]
# Epoch: 49, Test Accuracy: 61.33%
# Elapsed time NDSV(mfg_epochs=50, base_model=LogisticRegression, meta_interval=4, Ntime=5, batch_size=32, weight_decay=0.0005, meta_weight_decay=1e-05, meta_hidden_size=10): 0:00:39.217733
# CPU times: user 20min 31s, sys: 2.15 s, total: 20min 33s
# Wall time: 39.2 s

# %% [markdown]
# ## [Step 3] Evaluate data values

# %%
from dataval.experiment.exper_methods import (
    discover_corrupted_sample,
    noisy_detection,
    remove_high_low,
    remove_high_value,
    remove_low_value,
    add_low_high,
    add_high_value,
    add_low_value,
    save_dataval
)
from matplotlib import pyplot as plt

# %%
# Saving the results with percent 5%
percent = 0.05
output_dir = f"../results/NDDV_{device}_{dataset_name}_{model_name}_{noise_type}_{noise_rate=}_{train_count=}_{percent=}/"
exper_med.set_output_directory(output_dir)
output_dir
# Out:
# '../results/NDDV_cpu_pol_LogisticRegression_gauss_labels_noise_rate=0.45_train_count=1000_percent=0.05/'

# %% [markdown]
# ### Noisy data detection
# - `noisy_detection` performs the noisy data detection task and evaluates the F1-score of each data valuation algorithm's prediction. The higher, the better.
#   - noisy data: mislabeled data

# %%
exper_med.evaluate(noisy_detection, save_output=True)
# Out:
#                                                     kmeans_f1
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...   0.454545

# %% [markdown]
# ### Discover noisy samples
# - `discover_corrupted_sample` visualizes how well noisy data points are identified when a fraction of dataset is inspected.

# %%
fig = plt.figure(figsize=(18, 8))
df, fig = exper_med.plot(discover_corrupted_sample, fig, col=2, percnet=percent, save_output=True)

# %% [markdown]
# ### Point removal experiment
# - `remove_high_low` performs the point removal experiment. Each data valution algorithm, it provides two curves: one is removing data in a descending order (orange), the other is in an ascending order (blue). As for the orange (resp. blue) curve, the lower (resp. upper), the better.

# %%
fig = plt.figure(figsize=(18, 8))
df_resp, fig = exper_med.plot(remove_high_low, fig, col=2, percnet=percent, save_output=True)

# %%
fig = plt.figure(figsize=(18, 8))
df, fig = exper_med.plot(remove_high_value, fig, col=2, percnet=percent, save_output=True)

# %%
fig = plt.figure(figsize=(18, 8))
df, fig = exper_med.plot(remove_low_value, fig, col=2, percnet=percent, save_output=True)

# %%
df_resp # it provides complete information for generating point-removal experiment figures.
# Out:
#                                                    remove_least_influential_first_Metrics.ACCURACY  \
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                        0.876667
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                        0.866667
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                             0.9
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                            0.87
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                        0.853333
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                        0.846667
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                        0.863333
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                            0.84
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                            0.82
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                        0.843333
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                            0.85
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                        0.853333
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                        0.823333
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                        0.806667
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                        0.736667
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                            0.63
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                        0.573333
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                            0.57
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                        0.536667
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                        0.516667
#
#                                                    remove_most_influential_first_Metrics.ACCURACY  \
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                           0.87
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                           0.87
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                       0.866667
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                       0.836667
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                       0.803333
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                           0.75
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                       0.733333
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                       0.686667
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                       0.696667
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                           0.65
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                       0.673333
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                           0.64
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                       0.643333
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                       0.636667
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                       0.633333
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                       0.636667
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                           0.63
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                       0.613333
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                           0.55
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                       0.466667
#
#                                                     axis
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...   0.0
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...  0.05
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...   0.1
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...  0.15
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...   0.2
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...  0.25
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...   0.3
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...  0.35
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...   0.4
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...  0.45
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...   0.5
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...  0.55
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...   0.6
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...  0.65
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...   0.7
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...  0.75
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...   0.8
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...  0.85
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...   0.9
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...  0.95

# %%
fig = plt.figure(figsize=(18, 8))
df_addp, fig = exper_med.plot(add_low_high, fig, col=2, percnet=percent, save_output=True)

# %%
fig = plt.figure(figsize=(18, 8))
df, fig = exper_med.plot(add_high_value, fig, col=2, percnet=percent, save_output=True)

# %%
fig = plt.figure(figsize=(18, 8))
df, fig = exper_med.plot(add_low_value, fig, col=2, percnet=percent, save_output=True)

# %%
df_addp
# Out:
#                                                    add_least_influential_first_Metrics.ACCURACY  \
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                         0.55
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                     0.616667
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                     0.633333
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                         0.63
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                     0.636667
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                         0.63
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                         0.65
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                         0.62
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                         0.64
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                         0.66
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                     0.686667
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                          0.7
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                         0.73
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                     0.766667
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                     0.796667
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                     0.846667
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                         0.87
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                         0.87
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                     0.866667
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                     0.883333
#
#                                                    add_most_influential_first_Metrics.ACCURACY  \
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                    0.876667
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                        0.88
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                        0.87
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                    0.883333
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                    0.876667
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                    0.876667
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                    0.873333
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                    0.873333
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                    0.873333
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                        0.88
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                    0.883333
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                        0.87
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                    0.886667
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                    0.876667
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                    0.883333
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                        0.88
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                    0.876667
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                        0.89
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                        0.87
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...                                        0.87
#
#                                                     axis
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...  0.95
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...   0.9
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...  0.85
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...   0.8
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...  0.75
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...   0.7
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...  0.65
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...   0.6
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...  0.55
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...   0.5
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...  0.45
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...   0.4
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...  0.35
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...   0.3
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...  0.25
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...   0.2
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...  0.15
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...   0.1
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...  0.05
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...   0.0

# %% [markdown]
# ### Save data values
# - `save_dataval` stores computed data values at `{output_dir}/save_dataval.csv`.

# %%
exper_med.evaluate(save_dataval, save_output=True)
# Out:
#                                                    indices data_values
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...    8765    0.004564
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...    9158    0.006863
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...    8093      0.0038
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...   10074   -0.005835
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...    2894     0.00514
# ...                                                    ...         ...
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...   13032     0.00271
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...    5838    0.026437
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...    1086    0.015368
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...    6444    0.061666
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...   10845   -0.037242
#
# [1000 rows x 2 columns]

# %% [markdown]
# ### percent is 0.1

# %%
# Saving the results with percent 10%
percent = 0.1
output_dir = f"../results/NDDV_{device}_{dataset_name}_{model_name}_{noise_type}_{noise_rate=}_{train_count=}_{percent=}/"
exper_med.set_output_directory(output_dir)
output_dir
# Out:
# '../results/NDDV_cpu_pol_LogisticRegression_gauss_labels_noise_rate=0.45_train_count=1000_percent=0.1/'

# %%
exper_med.evaluate(noisy_detection, save_output=True)
# Out:
#                                                     kmeans_f1
# NDSV(mfg_epochs=50, base_model=LogisticRegressi...   0.454545

# %%
fig = plt.figure(figsize=(18, 8))
df, fig = exper_med.plot(discover_corrupted_sample, fig, col=2, percnet=percent, save_output=True)

# %%
fig = plt.figure(figsize=(18, 8))
df_resp, fig = exper_med.plot(remove_high_low, fig, col=2, percnet=percent, save_output=True)

# %%
fig = plt.figure(figsize=(18, 8))
df, fig = exper_med.plot(remove_high_value, fig, col=2, percnet=percent, save_output=True)

# %%
fig = plt.figure(figsize=(18, 8))
df, fig = exper_med.plot(remove_low_value, fig, col=2, percnet=percent, save_output=True)

# %%
fig = plt.figure(figsize=(18, 8))
df_resp, fig = exper_med.plot(add_low_high, fig, col=2, percnet=percent, save_output=True)

# %%
fig = plt.figure(figsize=(18, 8))
df, fig = exper_med.plot(add_high_value, fig, col=2, percnet=percent, save_output=True)

# %%
fig = plt.figure(figsize=(18, 8))
df, fig = exper_med.plot(add_low_value, fig, col=2, percnet=percent, save_output=True)
