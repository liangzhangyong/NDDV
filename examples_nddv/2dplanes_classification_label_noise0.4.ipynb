# %% [markdown]
# # 2dplanes dataset

# %%
# Imports
import os
import sys
BASE_DIR = os.path.dirname(os.getcwd())
sys.path.append(BASE_DIR)
import torch
import numpy as np
import pandas as pd

# Opendataval
from dataval.dataloader import Register, DataFetcher, mix_labels, add_gauss_noise
from dataval.datavaluation import NDDV, NDSV
from dataval.experiment import ExperimentMediator

import warnings
warnings.filterwarnings("ignore")
# Out:
# [KeOps] Warning :
#     The default C++ compiler could not be found on your system.
#     You need to either define the CXX environment variable or a symlink to the g++ command.
#     For example if g++-8 is the command you can do
#       import os
#       os.environ['CXX'] = 'g++-8'
#
# [KeOps] Warning : Cuda libraries were not detected on the system ; using cpu only mode

# %%
DataFetcher.datasets_available()
# Out:
# {'2dplanes',
#  'MiniBooNE',
#  'adult',
#  'bbc',
#  'bbc-embeddings',
#  'breast_cancer',
#  'challenge-iris',
#  'cifar10',
#  'cifar10-embeddings',
#  'cifar100',
#  'cifar100-embeddings',
#  'creditcard',
#  'diabetes',
#  'digits',
#  'echoMonths',
#  'election',
#  'electricity',
#  'fashion',
#  'fmnist-embeddings',
#  'fried',
#  'gaussian_classifier',
#  'gaussian_classifier_high_dim',
#  'imdb',
#  'imdb-embeddings',
#  'iris',
#  'linnerud',
#  'lowbwt',
#  'mnist',
#  'mnist-embeddings',
#  'mv',
#  'nomao',
#  'pol',
#  'stl10-embeddings',
#  'stock',
#  'svhn-embeddings',
#  'vehicle_sensIT',
#  'wave_energy',
#  'webdata_wXa'}

# %% [markdown]
# ## [Step 1] Set up an environment
# `ExperimentMediator` is a fundamental concept in establishing the `opendataval` environment. It empowers users to configure hyperparameters, including a dataset, a type of synthetic noise, and a prediction model. With  `ExperimentMediator`, users can effortlessly compute various data valuation algorithms.
#
# The following code cell demonstrates how to set up `ExperimentMediator` with a pre-registered dataset and a prediction model.
# - Dataset: adult
# - Model: sklearn's logistic regression model
# - Metric: Classification accuracy

# %%
dataset_name = "2dplanes"
train_count, valid_count, test_count, meta_count = 1000, 100, 300, 100
noise_rate = 0.4
noise_kwargs = {'noise_rate': noise_rate}
max_epoch = 3
batch_size = 32
lr = 0.01
random_state = 42
train_kwargs = {"epochs": max_epoch, "batch_size": batch_size, "lr": lr}
model_name = "classifiermlp"   # "sklogreg"
# model_name = "LogisticRegression"
metric_name = "accuracy"
cache_dir = "../data_files/"
add_noise = mix_labels
noise_type = "mix_labels"
device = 'cpu'

exper_med = ExperimentMediator.model_factory_setup(
    dataset_name=dataset_name,
    cache_dir=cache_dir,  
    force_download=False,
    train_count=train_count,
    valid_count=valid_count,
    test_count=test_count,
    meta_count=meta_count,
    add_noise=add_noise, 
    noise_kwargs=noise_kwargs,
    train_kwargs=train_kwargs,
    random_state = random_state,
    model_name=model_name,
    metric_name=metric_name,
    device=device
)
# Out:
# Base line model metric_name='accuracy': perf=0.7366666793823242

# %% [markdown]
# A full list of registered datasets can be found [here](https://github.com/opendataval/opendataval/blob/main/opendataval/dataloader/fetcher.py#L121). A list of available  prediction models can be found [here](https://github.com/opendataval/opendataval/blob/main/opendataval/model/__init__.py#L111).

# %% [markdown]
# ## [Step 2] Compute data values
# `opendataval` provides various state-of-the-art data valuation algorithms. `ExperimentMediator.compute_data_values()` computes data values.

# %%
# data_evaluators = [NDSV(mfg_epochs=50, base_model=model_name, meta_interval=4, Ntime=2, batch_size=batch_size, weight_decay=3e-4, meta_weight_decay=1e-4, meta_hidden_size=10)] 
data_evaluators = [NDSV(mfg_epochs=50, base_model=model_name, meta_interval=4, Ntime=3, batch_size=batch_size, weight_decay=2.9e-4, meta_weight_decay=0, meta_hidden_size=100)]

# %%
# %%time
# compute data values.
exper_med = exper_med.compute_data_values(data_evaluators=data_evaluators)
# Out:
#   2%|▏         | 1/50 [00:00<00:23,  2.09it/s]
# Epoch: 0, Test Accuracy: 52.00%
#   4%|▍         | 2/50 [00:01<00:24,  1.96it/s]
# Epoch: 1, Test Accuracy: 63.00%
#   6%|▌         | 3/50 [00:01<00:23,  1.96it/s]
# Epoch: 2, Test Accuracy: 65.00%
#   8%|▊         | 4/50 [00:02<00:24,  1.91it/s]
# Epoch: 3, Test Accuracy: 66.00%
#  10%|█         | 5/50 [00:02<00:22,  1.98it/s]
# Epoch: 4, Test Accuracy: 61.00%
#  12%|█▏        | 6/50 [00:03<00:21,  2.01it/s]
# Epoch: 5, Test Accuracy: 67.33%
#  14%|█▍        | 7/50 [00:03<00:21,  2.04it/s]
# Epoch: 6, Test Accuracy: 64.67%
#  16%|█▌        | 8/50 [00:03<00:20,  2.07it/s]
# Epoch: 7, Test Accuracy: 63.00%
#  18%|█▊        | 9/50 [00:04<00:21,  1.92it/s]
# Epoch: 8, Test Accuracy: 63.67%
#  20%|██        | 10/50 [00:05<00:20,  1.96it/s]
# Epoch: 9, Test Accuracy: 59.67%
#  22%|██▏       | 11/50 [00:05<00:19,  2.03it/s]
# Epoch: 10, Test Accuracy: 65.67%
#  24%|██▍       | 12/50 [00:05<00:18,  2.05it/s]
# Epoch: 11, Test Accuracy: 71.67%
#  26%|██▌       | 13/50 [00:06<00:17,  2.06it/s]
# Epoch: 12, Test Accuracy: 76.67%
#  28%|██▊       | 14/50 [00:06<00:17,  2.07it/s]
# Epoch: 13, Test Accuracy: 80.00%
#  30%|███       | 15/50 [00:07<00:16,  2.09it/s]
# Epoch: 14, Test Accuracy: 77.33%
#  32%|███▏      | 16/50 [00:07<00:16,  2.10it/s]
# Epoch: 15, Test Accuracy: 75.67%
#  34%|███▍      | 17/50 [00:08<00:17,  1.92it/s]
# Epoch: 16, Test Accuracy: 63.67%
#  36%|███▌      | 18/50 [00:08<00:16,  1.96it/s]
# Epoch: 17, Test Accuracy: 67.67%
#  38%|███▊      | 19/50 [00:09<00:15,  2.02it/s]
# Epoch: 18, Test Accuracy: 60.33%
#  40%|████      | 20/50 [00:10<00:15,  1.93it/s]
# Epoch: 19, Test Accuracy: 50.00%
#  42%|████▏     | 21/50 [00:10<00:14,  1.95it/s]
# Epoch: 20, Test Accuracy: 58.00%
#  44%|████▍     | 22/50 [00:10<00:13,  2.03it/s]
# Epoch: 21, Test Accuracy: 70.00%
#  46%|████▌     | 23/50 [00:11<00:13,  2.04it/s]
# Epoch: 22, Test Accuracy: 67.67%
#  48%|████▊     | 24/50 [00:11<00:12,  2.05it/s]
# Epoch: 23, Test Accuracy: 68.67%
#  50%|█████     | 25/50 [00:12<00:12,  2.08it/s]
# Epoch: 24, Test Accuracy: 76.67%
#  52%|█████▏    | 26/50 [00:12<00:11,  2.00it/s]
# Epoch: 25, Test Accuracy: 76.00%
#  54%|█████▍    | 27/50 [00:13<00:11,  2.04it/s]
# Epoch: 26, Test Accuracy: 76.00%
#  56%|█████▌    | 28/50 [00:13<00:10,  2.08it/s]
# Epoch: 27, Test Accuracy: 56.00%
#  58%|█████▊    | 29/50 [00:14<00:09,  2.12it/s]
# Epoch: 28, Test Accuracy: 50.67%
#  60%|██████    | 30/50 [00:14<00:09,  2.16it/s]
# Epoch: 29, Test Accuracy: 73.33%
#  62%|██████▏   | 31/50 [00:15<00:08,  2.18it/s]
# Epoch: 30, Test Accuracy: 77.00%
#  64%|██████▍   | 32/50 [00:15<00:08,  2.19it/s]
# Epoch: 31, Test Accuracy: 74.33%
#  66%|██████▌   | 33/50 [00:16<00:07,  2.20it/s]
# Epoch: 32, Test Accuracy: 71.67%
#  68%|██████▊   | 34/50 [00:16<00:07,  2.19it/s]
# Epoch: 33, Test Accuracy: 76.67%
#  70%|███████   | 35/50 [00:17<00:07,  2.07it/s]
# Epoch: 34, Test Accuracy: 73.33%
#  72%|███████▏  | 36/50 [00:17<00:06,  2.10it/s]
# Epoch: 35, Test Accuracy: 75.33%
#  74%|███████▍  | 37/50 [00:18<00:06,  2.15it/s]
# Epoch: 36, Test Accuracy: 73.67%
#  76%|███████▌  | 38/50 [00:18<00:05,  2.16it/s]
# Epoch: 37, Test Accuracy: 76.33%
#  78%|███████▊  | 39/50 [00:18<00:05,  2.17it/s]
# Epoch: 38, Test Accuracy: 76.00%
#  80%|████████  | 40/50 [00:19<00:04,  2.21it/s]
# Epoch: 39, Test Accuracy: 79.33%
#  82%|████████▏ | 41/50 [00:19<00:04,  2.22it/s]
# Epoch: 40, Test Accuracy: 79.67%
#  84%|████████▍ | 42/50 [00:20<00:03,  2.21it/s]
# Epoch: 41, Test Accuracy: 79.00%
#  86%|████████▌ | 43/50 [00:20<00:03,  2.22it/s]
# Epoch: 42, Test Accuracy: 73.67%
#  88%|████████▊ | 44/50 [00:21<00:02,  2.12it/s]
# Epoch: 43, Test Accuracy: 77.00%
#  90%|█████████ | 45/50 [00:21<00:02,  2.13it/s]
# Epoch: 44, Test Accuracy: 78.00%
#  92%|█████████▏| 46/50 [00:22<00:01,  2.15it/s]
# Epoch: 45, Test Accuracy: 76.00%
#  94%|█████████▍| 47/50 [00:22<00:01,  2.16it/s]
# Epoch: 46, Test Accuracy: 78.67%
#  96%|█████████▌| 48/50 [00:23<00:00,  2.18it/s]
# Epoch: 47, Test Accuracy: 70.00%
#  98%|█████████▊| 49/50 [00:23<00:00,  2.19it/s]
# Epoch: 48, Test Accuracy: 75.00%
# 100%|██████████| 50/50 [00:23<00:00,  2.09it/s]
# Epoch: 49, Test Accuracy: 79.33%
# Elapsed time NDSV(mfg_epochs=50, base_model=classifiermlp, meta_interval=4, Ntime=3, batch_size=32, weight_decay=0.00029, meta_weight_decay=0, meta_hidden_size=100): 0:00:24.162235
# CPU times: total: 2min 6s
# Wall time: 24.2 s

# %% [markdown]
# ## [Step 3] Evaluate data values

# %%
from dataval.experiment.exper_methods import (
    dynamic_data_state,
    dynamic_data_values,
    extract_loss,
    discover_corrupted_sample,
    noisy_detection,
    remove_high_low,
    remove_high_value,
    remove_low_value,
    add_low_high,
    add_high_value,
    add_low_value,
    save_dataval
)
from matplotlib import pyplot as plt

# %%
# Saving the results with percent 5%
percent = 0.05
output_dir = f"../results/NDDV_traj_{dataset_name}_{model_name}_{noise_type}_{noise_rate=}_{train_count=}_{percent=}/"
exper_med.set_output_directory(output_dir)
output_dir
# Out:
# '../results/NDDV_traj_2dplanes_classifiermlp_mix_labels_noise_rate=0.4_train_count=1000_percent=0.05/'

# %% [markdown]
# ### Noisy data detection
# - `noisy_detection` performs the noisy data detection task and evaluates the F1-score of each data valuation algorithm's prediction. The higher, the better.
#   - noisy data: mislabeled data

# %%
exper_med.evaluate(noisy_detection, save_output=True)
# Out:
#                                                     kmeans_f1
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.722787

# %% [markdown]
# ### Discover noisy samples
# - `discover_corrupted_sample` visualizes how well noisy data points are identified when a fraction of dataset is inspected.

# %%
fig = plt.figure(figsize=(18, 8))
df, fig = exper_med.plot(discover_corrupted_sample, fig, col=2, percnet=percent, save_output=True)

# %% [markdown]
# ### Point removal experiment
# - `remove_high_low` performs the point removal experiment. Each data valution algorithm, it provides two curves: one is removing data in a descending order (orange), the other is in an ascending order (blue). As for the orange (resp. blue) curve, the lower (resp. upper), the better.

# %%
fig = plt.figure(figsize=(18, 8))
df_resp, fig = exper_med.plot(remove_high_low, fig, col=2, percnet=percent, save_output=True)

# %%
fig = plt.figure(figsize=(18, 8))
df, fig = exper_med.plot(remove_high_value, fig, col=2, percnet=percent, save_output=True)

# %%
fig = plt.figure(figsize=(18, 8))
df, fig = exper_med.plot(remove_low_value, fig, col=2, percnet=percent, save_output=True)

# %%
df_resp # it provides complete information for generating point-removal experiment figures.
# Out:
#                                                    remove_least_influential_first_Metrics.ACCURACY  \
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                            0.61
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                        0.733333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                        0.803333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                            0.81
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                            0.78
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                        0.826667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                             0.8
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                        0.826667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                        0.796667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                        0.803333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                            0.82
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                        0.796667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                        0.783333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                        0.803333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                            0.77
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                        0.763333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                            0.74
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                        0.733333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                             0.6
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                            0.45
#
#                                                    remove_most_influential_first_Metrics.ACCURACY  \
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                       0.513333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                       0.623333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                       0.446667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                       0.513333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                           0.33
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                           0.25
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                           0.27
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                           0.27
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                       0.216667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                       0.243333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                       0.216667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                       0.226667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                       0.226667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                       0.203333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                       0.236667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                           0.22
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                       0.256667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                       0.276667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                       0.363333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                           0.52
#
#                                                     axis
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.0
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...  0.05
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.1
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...  0.15
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.2
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...  0.25
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.3
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...  0.35
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.4
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...  0.45
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.5
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...  0.55
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.6
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...  0.65
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.7
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...  0.75
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.8
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...  0.85
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.9
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...  0.95

# %%
fig = plt.figure(figsize=(18, 8))
df_addp, fig = exper_med.plot(add_low_high, fig, col=2, percnet=percent, save_output=True)

# %%
fig = plt.figure(figsize=(18, 8))
df, fig = exper_med.plot(add_high_value, fig, col=2, percnet=percent, save_output=True)

# %%
fig = plt.figure(figsize=(18, 8))
df, fig = exper_med.plot(add_low_value, fig, col=2, percnet=percent, save_output=True)

# %%
df_addp
# Out:
#                                                    add_least_influential_first_Metrics.ACCURACY  \
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                     0.346667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                     0.273333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                     0.256667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                         0.26
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                         0.23
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                         0.23
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                     0.196667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                         0.24
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                     0.213333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                     0.206667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                         0.22
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                     0.213333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                     0.283333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                         0.25
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                     0.326667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                     0.376667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                         0.55
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                         0.55
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                          0.6
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                     0.693333
#
#                                                    add_most_influential_first_Metrics.ACCURACY  \
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                    0.753333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                    0.756667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                        0.73
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                    0.473333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                    0.696667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                    0.776667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                    0.823333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                        0.78
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                    0.643333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                    0.766667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                    0.673333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                        0.75
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                    0.823333
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                        0.73
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                    0.836667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                        0.73
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                    0.656667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                    0.716667
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                         0.7
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...                                        0.67
#
#                                                     axis
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...  0.95
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.9
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...  0.85
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.8
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...  0.75
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.7
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...  0.65
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.6
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...  0.55
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.5
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...  0.45
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.4
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...  0.35
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.3
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...  0.25
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.2
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...  0.15
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.1
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...  0.05
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.0

# %% [markdown]
# ### Save data values
# - `save_dataval` stores computed data values at `{output_dir}/save_dataval.csv`.

# %%
exper_med.evaluate(save_dataval, save_output=True)
# Out:
#                                                    indices data_values
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...    7323   -0.000888
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...    7003    -0.00666
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   29534    0.000944
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   23677   -0.000369
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   29695    -0.00564
# ...                                                    ...         ...
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   24560    0.000546
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...    6418   -0.018024
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   15188    0.004296
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   38435     0.00234
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...    8339    0.000095
#
# [1000 rows x 2 columns]

# %% [markdown]
# ### percent is 0.1

# %%
# Saving the results with percent 10%
percent = 0.1
output_dir = f"../results/NDDV_traj_{dataset_name}_{model_name}_{noise_type}_{noise_rate=}_{train_count=}_{percent=}/"
exper_med.set_output_directory(output_dir)
output_dir
# Out:
# '../results/NDDV_traj_2dplanes_classifiermlp_mix_labels_noise_rate=0.4_train_count=1000_percent=0.1/'

# %%
exper_med.evaluate(noisy_detection, save_output=True)
# Out:
#                                                     kmeans_f1
# NDSV(mfg_epochs=50, base_model=classifiermlp, m...   0.722787

# %%
fig = plt.figure(figsize=(18, 8))
df, fig = exper_med.plot(discover_corrupted_sample, fig, col=2, percnet=percent, save_output=True)

# %%
fig = plt.figure(figsize=(18, 8))
df_resp, fig = exper_med.plot(remove_high_low, fig, col=2, percnet=percent, save_output=True)

# %%
fig = plt.figure(figsize=(18, 8))
df, fig = exper_med.plot(remove_high_value, fig, col=2, percnet=percent, save_output=True)

# %%
fig = plt.figure(figsize=(18, 8))
df, fig = exper_med.plot(remove_low_value, fig, col=2, percnet=percent, save_output=True)

# %%
fig = plt.figure(figsize=(18, 8))
df_resp, fig = exper_med.plot(add_low_high, fig, col=2, percnet=percent, save_output=True)

# %%
fig = plt.figure(figsize=(18, 8))
df, fig = exper_med.plot(add_high_value, fig, col=2, percnet=percent, save_output=True)

# %%
fig = plt.figure(figsize=(18, 8))
df, fig = exper_med.plot(add_low_value, fig, col=2, percnet=percent, save_output=True)
